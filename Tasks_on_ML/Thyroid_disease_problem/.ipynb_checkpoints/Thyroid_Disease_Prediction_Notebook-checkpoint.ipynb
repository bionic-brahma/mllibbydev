# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv("Data/allbp.data")
data.columns= ["age","sex","on_thyroxine","query_on_thyroxine","on_antithyroid_medication","sick","pregnant","thyroid_surgery","I131_treatment", "query_hypothyroid","query_hyperthyroid","lithium","goitre","tumor","hypopituitary","psych","TSH_measured","TSH","T3_measured","T3","TT4_measured","TT4","T4U_measured","T4U","FTI_measured","FTI","TBG_measured","TBG","Referral_source", "Class"]
# columns=["age","sex","on_thyroxine","query_on_thyroxine","on_antithyroid_medication","sick","pregnant","thyroid_surgery","I131_treatment", "query_hypothyroid","query_hyperthyroid","lithium","goitre","tumor","hypopituitary","psych","TSH_measured","TSH","T3_measured","T3","TT4_measured","TT4","T4U_measured","T4U","FTI_measured","FTI","TBG_measured","TBG","Referral_source", "Class"]
data.head(500)
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0    23   F            f                  f                         f    f
# 1    46   M            f                  f                         f    f
# 2    70   F            t                  f                         f    f
# 3    70   F            f                  f                         f    f
# 4    18   F            t                  f                         f    f
# ..   ..  ..          ...                ...                       ...  ...
# 495  45   F            f                  f                         f    f
# 496  82   M            f                  t                         f    f
# 497  55   F            f                  f                         f    f
# 498  43   M            f                  f                         f    f
# 499  79   M            f                  f                         f    f
#
#     pregnant thyroid_surgery I131_treatment query_hypothyroid  ...  \
# 0          f               f              f                 f  ...
# 1          f               f              f                 f  ...
# 2          f               f              f                 f  ...
# 3          f               f              f                 f  ...
# 4          f               f              f                 f  ...
# ..       ...             ...            ...               ...  ...
# 495        f               f              f                 f  ...
# 496        f               f              f                 f  ...
# 497        f               f              f                 f  ...
# 498        f               f              f                 f  ...
# 499        f               f              f                 f  ...
#
#     TT4_measured  TT4 T4U_measured   T4U FTI_measured  FTI TBG_measured TBG  \
# 0              t  102            f     ?            f    ?            f   ?
# 1              t  109            t  0.91            t  120            f   ?
# 2              t  175            f     ?            f    ?            f   ?
# 3              t   61            t  0.87            t   70            f   ?
# 4              t  183            t   1.3            t  141            f   ?
# ..           ...  ...          ...   ...          ...  ...          ...  ..
# 495            t  144            f     ?            f    ?            f   ?
# 496            t  133            t     1            t  134            f   ?
# 497            t  144            t  1.24            t  116            f   ?
# 498            t   62            t  0.94            t   66            f   ?
# 499            t   92            t  0.88            t  105            f   ?
#
#     Referral_source           Class
# 0             other  negative.|1442
# 1             other  negative.|2965
# 2             other   negative.|806
# 3               SVI  negative.|2807
# 4             other  negative.|3434
# ..              ...             ...
# 495           other  negative.|2185
# 496             SVI  negative.|1981
# 497           other  negative.|1327
# 498           other   negative.|169
# 499             SVI   negative.|692
#
# [500 rows x 30 columns]

# %%
data["Class"]= [x.split(".")[0] for x in data["Class"]]

# %%
def SearchKeyInColumns(dataset, key="NaN"):
    data= dataset.copy()
    cols=data.columns
    column_search_freq_dictionary={}
    for i in cols:
        count=0
        for j in data[i]:
            if j==key:
                count=count+1
        column_search_freq_dictionary[i]= count
        
    return column_search_freq_dictionary

# %%
print(SearchKeyInColumns(data, key="?"))
# Out:
# {'age': 1, 'sex': 110, 'on_thyroxine': 0, 'query_on_thyroxine': 0, 'on_antithyroid_medication': 0, 'sick': 0, 'pregnant': 0, 'thyroid_surgery': 0, 'I131_treatment': 0, 'query_hypothyroid': 0, 'query_hyperthyroid': 0, 'lithium': 0, 'goitre': 0, 'tumor': 0, 'hypopituitary': 0, 'psych': 0, 'TSH_measured': 0, 'TSH': 284, 'T3_measured': 0, 'T3': 585, 'TT4_measured': 0, 'TT4': 184, 'T4U_measured': 0, 'T4U': 297, 'FTI_measured': 0, 'FTI': 295, 'TBG_measured': 0, 'TBG': 2799, 'Referral_source': 0, 'Class': 0}

# %%
def RelevanceColumnFilter(dataset, key="NaN", filter_threshold=0.8):
    dictionary= SearchKeyInColumns(dataset, key)
    data= dataset.copy()
    columns_to_drop= []
    
    filter_threshold= filter_threshold*len(data)
    for i in dictionary.items():
        if i[1]>=filter_threshold:
            columns_to_drop.append(i[0])
    #print("Column to drop: ", columns_to_drop)
    data.drop(columns=columns_to_drop, inplace=True)
    
    return data

# %%
data= RelevanceColumnFilter(data, key="?", filter_threshold=0.8)

# %%
data
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     23   F            f                  f                         f    f
# 1     46   M            f                  f                         f    f
# 2     70   F            t                  f                         f    f
# 3     70   F            f                  f                         f    f
# 4     18   F            t                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 2794  70   M            f                  f                         f    f
# 2795  73   M            f                  t                         f    f
# 2796  75   M            f                  f                         f    f
# 2797  60   F            f                  f                         f    f
# 2798  81   F            f                  f                         f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...   T3  \
# 0           f               f              f                 f  ...    2
# 1           f               f              f                 f  ...    ?
# 2           f               f              f                 f  ...  1.9
# 3           f               f              f                 f  ...  1.2
# 4           f               f              f                 f  ...    ?
# ...       ...             ...            ...               ...  ...  ...
# 2794        f               f              f                 f  ...    ?
# 2795        f               f              f                 f  ...  0.7
# 2796        f               f              f                 f  ...    ?
# 2797        f               f              f                 f  ...    ?
# 2798        f               f              f                 f  ...  1.5
#
#      TT4_measured  TT4 T4U_measured   T4U FTI_measured  FTI TBG_measured  \
# 0               t  102            f     ?            f    ?            f
# 1               t  109            t  0.91            t  120            f
# 2               t  175            f     ?            f    ?            f
# 3               t   61            t  0.87            t   70            f
# 4               t  183            t   1.3            t  141            f
# ...           ...  ...          ...   ...          ...  ...          ...
# 2794            t  155            t  1.05            t  148            f
# 2795            t   63            t  0.88            t   72            f
# 2796            t  147            t   0.8            t  183            f
# 2797            t  100            t  0.83            t  121            f
# 2798            t  114            t  0.99            t  115            f
#
#      Referral_source     Class
# 0              other  negative
# 1              other  negative
# 2              other  negative
# 3                SVI  negative
# 4              other  negative
# ...              ...       ...
# 2794             SVI  negative
# 2795           other  negative
# 2796           other  negative
# 2797           other  negative
# 2798             SVI  negative
#
# [2799 rows x 29 columns]

# %%
def ReplaceMeanAndMode(dataset, key='NaN'):
    
    data= dataset.copy()
    cols= data.columns
    for i in cols:
        if not data[i][0].isalpha():
            total=0
            count=0
            total= sum([float(x) for x in np.array(data[i]) if x != key])
            count= sum([1.0 for x in np.array(data[i]) if x != key])
            mean=total/count
            data[i].replace(key, mean,inplace=True)
        else:
            data[i].replace(key,np.nan,inplace=True)
            data[i].replace(np.nan, data[i].mode(), inplace=True)
    
    return data

# %%
data= ReplaceMeanAndMode(data, key='?')

# %%
print(SearchKeyInColumns(data, key="?"))
# Out:
# {'age': 0, 'sex': 0, 'on_thyroxine': 0, 'query_on_thyroxine': 0, 'on_antithyroid_medication': 0, 'sick': 0, 'pregnant': 0, 'thyroid_surgery': 0, 'I131_treatment': 0, 'query_hypothyroid': 0, 'query_hyperthyroid': 0, 'lithium': 0, 'goitre': 0, 'tumor': 0, 'hypopituitary': 0, 'psych': 0, 'TSH_measured': 0, 'TSH': 0, 'T3_measured': 0, 'T3': 0, 'TT4_measured': 0, 'TT4': 0, 'T4U_measured': 0, 'T4U': 0, 'FTI_measured': 0, 'FTI': 0, 'TBG_measured': 0, 'Referral_source': 0, 'Class': 0}

# %%
print(SearchKeyInColumns(data, key=np.nan))
data
# Out:
# {'age': 0, 'sex': 0, 'on_thyroxine': 0, 'query_on_thyroxine': 0, 'on_antithyroid_medication': 0, 'sick': 0, 'pregnant': 0, 'thyroid_surgery': 0, 'I131_treatment': 0, 'query_hypothyroid': 0, 'query_hyperthyroid': 0, 'lithium': 0, 'goitre': 0, 'tumor': 0, 'hypopituitary': 0, 'psych': 0, 'TSH_measured': 0, 'TSH': 0, 'T3_measured': 0, 'T3': 0, 'TT4_measured': 0, 'TT4': 0, 'T4U_measured': 0, 'T4U': 0, 'FTI_measured': 0, 'FTI': 0, 'TBG_measured': 0, 'Referral_source': 0, 'Class': 0}
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     23   F            f                  f                         f    f
# 1     46   M            f                  f                         f    f
# 2     70   F            t                  f                         f    f
# 3     70   F            f                  f                         f    f
# 4     18   F            t                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 2794  70   M            f                  f                         f    f
# 2795  73   M            f                  t                         f    f
# 2796  75   M            f                  f                         f    f
# 2797  60   F            f                  f                         f    f
# 2798  81   F            f                  f                         f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...       T3  \
# 0           f               f              f                 f  ...        2
# 1           f               f              f                 f  ...  2.02475
# 2           f               f              f                 f  ...      1.9
# 3           f               f              f                 f  ...      1.2
# 4           f               f              f                 f  ...  2.02475
# ...       ...             ...            ...               ...  ...      ...
# 2794        f               f              f                 f  ...  2.02475
# 2795        f               f              f                 f  ...      0.7
# 2796        f               f              f                 f  ...  2.02475
# 2797        f               f              f                 f  ...  2.02475
# 2798        f               f              f                 f  ...      1.5
#
#      TT4_measured  TT4 T4U_measured       T4U FTI_measured      FTI  \
# 0               t  102            f  0.997855            f  110.789
# 1               t  109            t      0.91            t      120
# 2               t  175            f  0.997855            f  110.789
# 3               t   61            t      0.87            t       70
# 4               t  183            t       1.3            t      141
# ...           ...  ...          ...       ...          ...      ...
# 2794            t  155            t      1.05            t      148
# 2795            t   63            t      0.88            t       72
# 2796            t  147            t       0.8            t      183
# 2797            t  100            t      0.83            t      121
# 2798            t  114            t      0.99            t      115
#
#      TBG_measured Referral_source     Class
# 0               f           other  negative
# 1               f           other  negative
# 2               f           other  negative
# 3               f             SVI  negative
# 4               f           other  negative
# ...           ...             ...       ...
# 2794            f             SVI  negative
# 2795            f           other  negative
# 2796            f           other  negative
# 2797            f           other  negative
# 2798            f             SVI  negative
#
# [2799 rows x 29 columns]
